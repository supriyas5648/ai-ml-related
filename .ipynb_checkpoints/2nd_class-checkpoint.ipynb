# %%
name,age,height = "supriya",23,12.4

# %%
print(name,age)
# Out:
# supriya 23

# %% [markdown]
# INPUT AND OUTPUT

# %%
name = input("enter name: ")
print(name);
# Out:
# enter name:  Supriya
# Supriya

# %%
#format output

# %%
name = "Surpiya"
marks = 74
print(name + "has scored" + string(marks) + "out of 100")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 name = "Surpiya"
#       2 marks = 74
# ----> 3 print(name + "has scored" + string(marks) + "out of 100")
#
# NameError: name 'string' is not defined

# %%
name = "Surpiya"
marks = 74
print(f"{name} has scored {marks} out of 100")
print("scored marks ",marks)
## f statement
# Out:
# Surpiya has scored 74 out of 100
# scored marks  74

# %% [markdown]
#     LISTS!!!

# %%
fruits = ["bananna","apple","guava"]
fruits.append("grapes")
print(fruits)
# Out:
# ['bananna', 'apple', 'guava', 'grapes']

# %%
fruits[1] = "mango"
print(fruits)
# Out:
# ['bananna', 'mango', 'guava', 'grapes']

# %%
fruits.remove("bananna")
print(fruits)
# Out:
# ['mango', 'guava', 'grapes']

# %%
print(fruits[0:3])
# Out:
# ['mango', 'guava', 'grapes']

# %%
for i in range (4):
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
def stats(nums):
    return nums*10

# %%
print(stats(5))
# Out:
# 50

# %% [markdown]
# ## LIST COMPREHENSION

# %%
numbers = [1,2,3,4,5]
squares = [x*x for x in numbers]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
## tuples
cord = (10,20,30)
##storing list in tuples
record = [("allice",23),(23,"blavk")]
print(record)
# Out:
# [('allice', 23), (23, 'blavk')]

# %%
##dictionary

# %%
dict = {"name": "supriya","age":21}
print(dict)
# Out:
# {'name': 'supriya', 'age': 21}

# %% [markdown]
# # set

# %%
st = {1,2,3,4,5,}
st2 = {2,3,4,5,6}

print(st | st2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(st & st2)
print(st - st2)
# Out:
# {2, 3, 4, 5}
# {1}

# %% [markdown]
# # file handling

# %%
#write a file

# %%
with open("test.txt", "w") as f:
    f.write("hello")

# %%
#read a file

# %%
with open("test.txt", "r") as f:
    content = f.read()

print(content)
# Out:
# hello

# %% [markdown]
# # modules

# %%
import math

# %%
print(math.sqrt(25))
# Out:
# 5.0
