# %%
name = "alice"
age = 22
height = 198.1

# %%
print(name,height)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(name,height)
#
# NameError: name 'name' is not defined

# %%
name = "alice"
age = 22
height = 198.1
